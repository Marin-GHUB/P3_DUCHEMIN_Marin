# %%
import pymongo

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
# Se connecter en local

client = MongoClient('localhost', 27017)

# %%
# Liste des databases presentes

client.list_database_names()
# Out:
# ['Rohida_Armies', 'admin', 'config', 'local', 'rawDB']

# %%
# Se connecter sur la database

rawData = client.rawDB

# %%
# Montrer les collections de la database

rawData.list_collection_names()
# Out:
# ['products']

# %%
rawCollection = rawData['products']

# %%
# Afficher un document

import pprint

pprint.pprint(rawCollection.find_one())
# Out:
# {'_id': None,
#  '_keywords': [],
#  'additives_tags': [],
#  'categories_hierarchy': [],
#  'categories_tags': [],
#  'category_properties': {},
#  'checkers': [],
#  'checkers_tags': [],
#  'ciqual_food_name_tags': ['unknown'],
#  'code': '',
#  'complete': 0,
#  'correctors': [],
#  'correctors_tags': [],
#  'creator': 'nounours',
#  'informers': [],
#  'informers_tags': ['nounours'],
#  'ingredients_from_palm_oil_tags': [],
#  'ingredients_tags': [],
#  'ingredients_that_may_be_from_palm_oil_tags': [],
#  'labels_hierarchy': [],
#  'labels_tags': [],
#  'nutriments': {},
#  'nutrition_data_per': '100g',
#  'photographers': [],
#  'photographers_tags': ['nounours', 'stephane'],
#  'pnns_groups_1': 'unknown',
#  'pnns_groups_1_tags': ['unknown', 'missing-category'],
#  'pnns_groups_2': 'unknown',
#  'pnns_groups_2_tags': ['unknown', 'missing-category'],
#  'popularity_key': 0,
#  'serving_quantity': '0',
#  'sortkey': 0.0,
#  'states': 'en:to-be-completed, en:nutrition-facts-to-be-completed, '
#            'en:ingredients-to-be-completed, '
#            'en:expiration-date-to-be-completed, '
#            'en:characteristics-to-be-completed, en:categories-to-be-completed, '
#            'en:brands-to-be-completed, en:packaging-to-be-completed, '
#            'en:quantity-to-be-completed, en:product-name-to-be-completed, '
#            'en:photos-to-be-validated, en:photos-uploaded',
#  'states_hierarchy': ['en:to-be-completed',
#                       'en:nutrition-facts-to-be-completed',
#                       'en:ingredients-to-be-completed',
#                       'en:expiration-date-to-be-completed',
#                       'en:characteristics-to-be-completed',
#                       'en:categories-to-be-completed',
#                       'en:brands-to-be-completed',
#                       'en:packaging-to-be-completed',
#                       'en:quantity-to-be-completed',
#                       'en:product-name-to-be-completed',
#                       'en:photos-to-be-validated',
#                       'en:photos-uploaded'],
#  'states_tags': ['en:to-be-completed',
#                  'en:nutrition-facts-to-be-completed',
#                  'en:ingredients-to-be-completed',
#                  'en:expiration-date-to-be-completed',
#                  'en:characteristics-to-be-completed',
#                  'en:categories-to-be-completed',
#                  'en:brands-to-be-completed',
#                  'en:packaging-to-be-completed',
#                  'en:quantity-to-be-completed',
#                  'en:product-name-to-be-completed',
#                  'en:photos-to-be-validated',
#                  'en:photos-uploaded'],
#  'update_key': 'key_1594224308'}

# %%
rawCollection.estimated_document_count()
# Out:
# 1601557

# %%
rawCollection.count_documents({'ecoscore_data.missing.origins':1})
# Out:
# 732597

# %%
rawCollection.count_documents({'countries':'France'})
# Out:
# 425015

# %%
rawCollection.count_documents({'purchase_places': 'France'})
# Out:
# 40606

# %%
rawCollection.count_documents({'purchase_places': 'France', 'ecoscore_data.missing.origins':1})
# Out:
# 28209

# %%
dataMissing = 732597/1601557
dataMissingfr = 28209/40606
print('Il y a %s pourcent de produits sans origines au total et %s en France' %(dataMissing*100,dataMissingfr*100))
# Out:
# Il y a 45.742799038685476 pourcent de produits sans origines au total et 69.47002905974486 en France

# %%
dataFr = 40606 - 28209
dataAll = 1601557 - 732597
print(dataFr, dataAll)
# Out:
# 12397 868960

# %%
rawCollection.find_one({'countries':'France'},
                       {"ingredients.text":1,
                        "ingredients.vegan":1,
                        "ingredients.vegetarian":1,
                        "ecoscore_data.agribalyse.name_fr":1,
                        "code":1,
                        "countries":1,
                        "nutriscore_grade":1,
                        "categories":1,
                        "ecoscore_grade":1,
                        "product_name_fr":1
                       })
# Out:
# {'_id': 30383354190402,
#  'product_name_fr': 'basilic',
#  'ingredients': [{'text': 'Pulpe de tomates fraîches avec morceaux et purées de tomates fraîches'},
#   {'text': 'légumes frais', 'vegan': 'yes', 'vegetarian': 'yes'},
#   {'vegetarian': 'yes', 'vegan': 'yes', 'text': 'huile de tournesol'},
#   {'text': 'basilic', 'vegan': 'yes', 'vegetarian': 'yes'},
#   {'vegan': 'yes', 'text': 'sucre', 'vegetarian': 'yes'},
#   {'vegetarian': 'yes', 'vegan': 'yes', 'text': 'sel'},
#   {'vegan': 'yes', 'text': 'amidon transformé de maïs', 'vegetarian': 'yes'},
#   {'vegetarian': 'maybe', 'text': 'arôme naturel', 'vegan': 'maybe'},
#   {'vegan': 'yes', 'text': "extrait d'oignon", 'vegetarian': 'yes'},
#   {'vegetarian': 'yes', 'vegan': 'yes', 'text': 'persil'},
#   {'vegetarian': 'yes', 'vegan': 'yes', 'text': 'oignons'},
#   {'vegetarian': 'yes', 'vegan': 'yes', 'text': 'carottes'}],
#  'ecoscore_data': {'agribalyse': {'name_fr': 'Sauce tomate aux oignons, préemballée'}},
#  'code': '30383354190402',
#  'countries': 'France',
#  'nutriscore_grade': 'b',
#  'categories': 'Epicerie,Sauces,Sauces tomate',
#  'ecoscore_grade': 'b'}

# %%
rawCollection.find_one({'countries':'France'})
# Out:
# {'_id': 30383354190402,
#  'carbon_footprint_percent_of_known_ingredients': 7,
#  'countries_tags': ['en:france'],
#  'product_name_fr': 'basilic',
#  'categories_lc': 'fr',
#  'obsolete': '',
#  'allergens_from_ingredients': '',
#  'vitamins_tags': [],
#  'traces_lc': 'fr',
#  'labels': 'Nutriscore,Nutriscore A',
#  'ingredients': [{'id': 'fr:Pulpe de tomates fraîches avec morceaux et purées de tomates fraîches',
#    'percent_min': 85.0,
#    'percent': 85,
#    'percent_max': 85.0,
#    'rank': 1,
#    'text': 'Pulpe de tomates fraîches avec morceaux et purées de tomates fraîches',
#    'percent_estimate': 85.0},
#   {'text': 'légumes frais',
#    'vegan': 'yes',
#    'has_sub_ingredients': 'yes',
#    'ingredients': [{'percent_min': 3.5,
#      'id': 'en:onion',
#      'percent_max': 7.0,
#      'text': 'oignons',
#      'percent_estimate': 5.25},
#     {'id': 'en:carrot',
#      'percent_min': 0.0,
#      'percent_max': 3.5,
#      'percent_estimate': 1.75,
#      'text': 'carottes'}],
#    'percent_max': 7.0,
#    'id': 'fr:legumes-frais',
#    'percent': 7.0,
#    'percent_estimate': 7,
#    'rank': 2,
#    'percent_min': 7.0,
#    'vegetarian': 'yes'},
#   {'rank': 3,
#    'percent_min': 1.4,
#    'vegetarian': 'yes',
#    'percent_estimate': 4.2,
#    'id': 'en:sunflower-oil',
#    'percent_max': 7.0,
#    'from_palm_oil': 'no',
#    'vegan': 'yes',
#    'text': 'huile de tournesol'},
#   {'id': 'en:basil',
#    'percent': 1.4,
#    'percent_max': 1.4,
#    'text': 'basilic',
#    'vegan': 'yes',
#    'percent_min': 1.4,
#    'vegetarian': 'yes',
#    'rank': 4,
#    'percent_estimate': 1.4},
#   {'vegan': 'yes',
#    'text': 'sucre',
#    'percent_max': 1.4,
#    'id': 'en:sugar',
#    'percent_estimate': 0.7,
#    'percent_min': 0.0,
#    'vegetarian': 'yes',
#    'rank': 5},
#   {'rank': 6,
#    'percent_min': 0.0,
#    'vegetarian': 'yes',
#    'percent_estimate': 0.7,
#    'percent_max': 1.4,
#    'id': 'en:salt',
#    'vegan': 'yes',
#    'text': 'sel'},
#   {'vegan': 'yes',
#    'text': 'amidon transformé de maïs',
#    'percent_max': 1.4,
#    'id': 'en:modified-corn-starch',
#    'percent_estimate': 0.4999999999999929,
#    'vegetarian': 'yes',
#    'percent_min': 0.0,
#    'rank': 7},
#   {'percent_min': 0.0,
#    'vegetarian': 'maybe',
#    'rank': 8,
#    'percent_estimate': 0.25,
#    'percent_max': 1.099999999999999,
#    'id': 'en:natural-flavouring',
#    'text': 'arôme naturel',
#    'vegan': 'maybe'},
#   {'percent_max': 0.9428571428571421,
#    'id': 'en:onion-extract',
#    'vegan': 'yes',
#    'text': "extrait d'oignon",
#    'vegetarian': 'yes',
#    'percent_min': 0.0,
#    'rank': 9,
#    'percent_estimate': 0.125},
#   {'vegetarian': 'yes',
#    'percent_min': 0.0,
#    'rank': 10,
#    'percent_estimate': 0.125,
#    'id': 'en:parsley',
#    'percent_max': 0.8249999999999993,
#    'vegan': 'yes',
#    'text': 'persil'},
#   {'vegetarian': 'yes',
#    'percent_min': 3.5,
#    'id': 'en:onion',
#    'percent_max': 7.0,
#    'vegan': 'yes',
#    'text': 'oignons',
#    'percent_estimate': 5.25},
#   {'vegetarian': 'yes',
#    'id': 'en:carrot',
#    'percent_min': 0.0,
#    'percent_max': 3.5,
#    'vegan': 'yes',
#    'text': 'carottes',
#    'percent_estimate': 1.75}],
#  'stores_tags': [],
#  'ecoscore_data': {'grade': 'b',
#   'status': 'known',
#   'adjustments': {'production_system': {},
#    'packaging': {'warning': 'unspecified_shape',
#     'value': -1.9499999999999993,
#     'score': 80.5,
#     'packagings': [{'ecoscore_shape_ratio': 1.0,
#       'material': 'en:glass',
#       'ecoscore_material_score': 80.5,
#       'shape': 'en:unknown'}]},
#    'origins_of_ingredients': {'aggregated_origins': [{'origin': 'en:unknown',
#       'percent': 100.0}],
#     'epi_score': 0.0,
#     'epi_value': -5,
#     'origins_from_origins_field': ['en:unknown'],
#     'value': -5.0,
#     'warning': 'origins_are_100_percent_unknown',
#     'transportation_score': 0.0,
#     'transportation_value': 0.0},
#    'threatened_species': {}},
#   'agribalyse': {'ef_processing': '0.035916618',
#    'ef_consumption': '0.0064417627',
#    'name_fr': 'Sauce tomate aux oignons, préemballée',
#    'co2_consumption': '0.012726077',
#    'agribalyse_proxy_food_code': '11107',
#    'co2_packaging': '0.1959761',
#    'co2_distribution': '0.032692835',
#    'score': 85.3670138323676,
#    'ef_distribution': '0.0091648653',
#    'co2_agriculture': '0.27818016',
#    'co2_transportation': '0.26334763',
#    'dqr': '2.78',
#    'name_en': 'Tomato sauce, with onions, prepacked',
#    'co2_total': '0.95472916',
#    'code': '11107',
#    'ef_transportation': '0.020882611',
#    'ef_agriculture': '0.087732798',
#    'ef_packaging': '0.021358968',
#    'co2_processing': '0.17177889',
#    'ef_total': 0.1814997},
#   'missing_data_warning': 1,
#   'score': 78.4170138323676,
#   'missing': {'packagings': 1, 'origins': 1}},
#  'categories_tags': ['en:groceries', 'en:sauces', 'en:tomato-sauces'],
#  'purchase_places_tags': ['france'],
#  'rev': 25,
#  'nutrition_data_prepared_per': '100g',
#  'nova_groups': '4',
#  'unknown_ingredients_n': 1.0,
#  'languages_hierarchy': ['en:french'],
#  'ingredients_n': 12.0,
#  'expiration_date': '',
#  'countries_hierarchy': ['en:france'],
#  'nutriments': {'nova-group_serving': 4,
#   'sugars': 5.5,
#   'energy_value': 261,
#   'proteins_unit': 'g',
#   'nova-group_100g': 4,
#   'energy-kcal_unit': 'kcal',
#   'sodium_value': 0.396,
#   'energy_unit': 'kJ',
#   'proteins_100g': 1.7,
#   'energy_100g': 261,
#   'carbon-footprint-from-known-ingredients_product': 4.41,
#   'saturated-fat': 0.3,
#   'carbohydrates_100g': 6.1,
#   'salt_100g': 0.99,
#   'fiber': 2.2,
#   'energy': 261,
#   'energy-kj_value': 261,
#   'energy-kcal_100g': 63,
#   'sugars_100g': 5.5,
#   'fat_100g': 3,
#   'sodium_100g': 0.396,
#   'salt_value': 0.99,
#   'saturated-fat_unit': 'g',
#   'nutrition-score-fr_100g': 2,
#   'fruits-vegetables-nuts-estimate-from-ingredients_100g': 7,
#   'sodium': 0.396,
#   'proteins_value': 1.7,
#   'carbohydrates_unit': 'g',
#   'proteins': 1.7,
#   'nutrition-score-fr': 2,
#   'energy-kj_100g': 261,
#   'salt_unit': 'g',
#   'sugars_unit': 'g',
#   'sugars_value': 5.5,
#   'fat_value': 3,
#   'fiber_value': 2.2,
#   'energy-kj': 261,
#   'salt': 0.99,
#   'nova-group': 4,
#   'energy-kj_unit': 'kJ',
#   'fiber_unit': 'g',
#   'carbohydrates': 6.1,
#   'fiber_100g': 2.2,
#   'energy-kcal_value': 63,
#   'saturated-fat_value': 0.3,
#   'fat': 3,
#   'fat_unit': 'g',
#   'energy-kcal': 63,
#   'carbon-footprint-from-known-ingredients_100g': 2.1,
#   'carbohydrates_value': 6.1,
#   'saturated-fat_100g': 0.3,
#   'sodium_unit': 'g'},
#  'manufacturing_places': '',
#  'labels_tags': ['en:nutriscore', 'en:nutriscore-grade-a'],
#  'nova_groups_tags': ['en:4-ultra-processed-food-and-drink-products'],
#  'countries_lc': 'fr',
#  'editors_tags': ['sebleouf',
#   'openfoodfacts-contributors',
#   'kiliweb',
#   'yuka.UW8wQ0lyNGFoTVJSa3NJMzhVM3Arc2h0eU1XRmZFYVNOYk1iSVE9PQ',
#   'charlesnepote',
#   'roboto-app'],
#  'created_t': 1608035756,
#  'nutrition_grades': 'b',
#  'link': '',
#  'no_nutrition_data': '',
#  'generic_name': '',
#  'amino_acids_tags': [],
#  'lang': 'fr',
#  'ingredients_hierarchy': ['fr:Pulpe de tomates fraîches avec morceaux et purées de tomates fraîches',
#   'fr:legumes-frais',
#   'en:vegetable',
#   'en:sunflower-oil',
#   'en:oil-and-fat',
#   'en:vegetable-oil-and-fat',
#   'en:vegetable-oil',
#   'en:basil',
#   'en:herb',
#   'en:sugar',
#   'en:salt',
#   'en:modified-corn-starch',
#   'en:starch',
#   'en:corn-starch',
#   'en:modified-starch',
#   'en:natural-flavouring',
#   'en:flavouring',
#   'en:onion-extract',
#   'en:root-vegetable',
#   'en:onion',
#   'en:parsley',
#   'en:carrot'],
#  'data_quality_bugs_tags': [],
#  'packaging': 'verre',
#  'ecoscore_tags': ['b'],
#  'code': '30383354190402',
#  'packaging_text_fr': '',
#  '_keywords': ['basilic',
#   'sauce',
#   'tomate',
#   'epicerie',
#   'panzani',
#   'nutriscore'],
#  'labels_lc': 'fr',
#  'nutriscore_data': {'sugars': 5.5,
#   'energy_value': 261.0,
#   'sodium_value': 396.0,
#   'positive_points': 3,
#   'negative_points': 5,
#   'saturated_fat_value': 0.3,
#   'fiber': 2.2,
#   'energy': 261,
#   'saturated_fat_points': 0,
#   'fruits_vegetables_nuts_colza_walnut_olive_oils_points': 0,
#   'fruits_vegetables_nuts_colza_walnut_olive_oils_value': 7.0,
#   'saturated_fat': 0.3,
#   'sodium': 396.0,
#   'fiber_points': 2,
#   'proteins_points': 1,
#   'proteins_value': 1.7,
#   'proteins': 1.7,
#   'saturated_fat_ratio': 10.0,
#   'is_beverage': 0,
#   'is_cheese': 0,
#   'is_water': 0,
#   'energy_points': 0,
#   'sugars_value': 5.5,
#   'grade': 'b',
#   'sodium_points': 4,
#   'fiber_value': 2.2,
#   'sugars_points': 1,
#   'is_fat': 0,
#   'fruits_vegetables_nuts_colza_walnut_olive_oils': 7,
#   'saturated_fat_ratio_points': 1,
#   'score': 2,
#   'saturated_fat_ratio_value': 10.0},
#  'additives_tags': ['en:e14xx'],
#  'unknown_nutrients_tags': [],
#  'entry_dates_tags': ['2020-12-15', '2020-12', '2020'],
#  'data_quality_errors_tags': [],
#  'minerals_tags': [],
#  'categories_hierarchy': ['en:groceries', 'en:sauces', 'en:tomato-sauces'],
#  'carbon_footprint_from_known_ingredients_debug': 'fr:legumes-frais 7% x 0.3 = 2.1 g - ',
#  'pnns_groups_2_tags': ['dressings-and-sauces', 'known'],
#  'states_hierarchy': ['en:to-be-completed',
#   'en:nutrition-facts-completed',
#   'en:ingredients-completed',
#   'en:expiration-date-to-be-completed',
#   'en:packaging-code-to-be-completed',
#   'en:characteristics-to-be-completed',
#   'en:origins-to-be-completed',
#   'en:categories-completed',
#   'en:brands-completed',
#   'en:packaging-completed',
#   'en:quantity-completed',
#   'en:product-name-completed',
#   'en:photos-to-be-validated',
#   'en:packaging-photo-to-be-selected',
#   'en:nutrition-photo-selected',
#   'en:ingredients-photo-selected',
#   'en:front-photo-selected',
#   'en:photos-uploaded'],
#  'ingredients_that_may_be_from_palm_oil_n': 0,
#  'ingredients_text': "Pulpe de tomates fraîches avec morceaux et purées de tomates fraîches (85%), légumes frais 7% (oignons, carottes), huile de tournesol, basilic 1,4%, sucre, sel, amidon transformé de maïs, arôme naturel, extrait d'oignon, persil",
#  'traces': '',
#  'ingredients_original_tags': ['fr:Pulpe de tomates fraîches avec morceaux et purées de tomates fraîches',
#   'fr:legumes-frais',
#   'en:sunflower-oil',
#   'en:basil',
#   'en:sugar',
#   'en:salt',
#   'en:modified-corn-starch',
#   'en:natural-flavouring',
#   'en:onion-extract',
#   'en:parsley',
#   'en:onion',
#   'en:carrot'],
#  'countries': 'France',
#  'traces_from_user': '(fr) ',
#  'traces_from_ingredients': '',
#  'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients_value': 7,
#  'last_modified_by': 'charlesnepote',
#  'obsolete_since_date': '',
#  'update_key': 'ecoscore20210105b',
#  'emb_codes': '',
#  'known_ingredients_n': 21,
#  'product_quantity': 210.0,
#  'additives_old_n': 0,
#  'checkers_tags': [],
#  'traces_tags': [],
#  'data_sources': 'App - yuka, Apps',
#  'creator': 'openfoodfacts-contributors',
#  'other_nutritional_substances_tags': [],
#  'origins_hierarchy': [],
#  'debug_param_sorted_langs': ['fr'],
#  'id': '15161912',
#  'ingredients_n_tags': ['12', '11-20'],
#  'last_edit_dates_tags': ['2021-01-15', '2021-01', '2021'],
#  'lc': 'fr',
#  'max_imgid': '5',
#  'ingredients_from_palm_oil_tags': [],
#  'data_sources_tags': ['app-yuka', 'apps'],
#  'images': {'ingredients_fr': {'angle': '270',
#    'coordinates_image_size': 'full',
#    'x1': '671.1840087890623',
#    'imgid': '4',
#    'white_magic': 'false',
#    'sizes': {'full': {'w': 1594, 'h': 743},
#     '200': {'w': 200, 'h': 93},
#     '400': {'w': 400, 'h': 186},
#     '100': {'w': 100, 'h': 47}},
#    'rev': '22',
#    'geometry': '1594x743-671-1681',
#    'normalize': 'false',
#    'x2': '2265.2640087890622',
#    'y1': '1681.8480175781249',
#    'y2': '2424.888017578125'},
#   '4': {'sizes': {'100': {'w': 100, 'h': 75},
#     '400': {'h': 300, 'w': 400},
#     'full': {'w': 4608, 'h': 3456}},
#    'uploader': 'openfoodfacts-contributors',
#    'uploaded_t': 1608035892},
#   'nutrition_fr': {'geometry': '1654x1389-773-2337',
#    'normalize': 'false',
#    'y1': '2337.8874609375002',
#    'x2': '2427.07201171875',
#    'y2': '3726.0474609375005',
#    'angle': '0',
#    'coordinates_image_size': 'full',
#    'imgid': '5',
#    'x1': '773.95201171875',
#    'white_magic': 'false',
#    'sizes': {'full': {'h': 1389, 'w': 1654},
#     '400': {'h': 336, 'w': 400},
#     '200': {'w': 200, 'h': 168},
#     '100': {'h': 84, 'w': 100}},
#    'rev': '23'},
#   '3': {'uploaded_t': 1608035757,
#    'uploader': 'openfoodfacts-contributors',
#    'sizes': {'100': {'w': 60, 'h': 100},
#     '400': {'h': 400, 'w': 240},
#     'full': {'h': 3749, 'w': 2248}}},
#   '5': {'sizes': {'100': {'h': 100, 'w': 75},
#     '400': {'h': 400, 'w': 300},
#     'full': {'w': 3456, 'h': 4608}},
#    'uploader': 'openfoodfacts-contributors',
#    'uploaded_t': 1608035966},
#   'front_fr': {'imgid': '3',
#    'x1': None,
#    'angle': None,
#    'white_magic': None,
#    'sizes': {'100': {'w': 60, 'h': 100},
#     '200': {'h': 200, 'w': 120},
#     '400': {'h': 400, 'w': 240},
#     'full': {'w': 2248, 'h': 3749}},
#    'rev': '14',
#    'geometry': '0x0-0-0',
#    'y1': None,
#    'x2': None,
#    'normalize': None,
#    'y2': None}},
#  'correctors_tags': ['openfoodfacts-contributors', 'charlesnepote'],
#  'languages_tags': ['en:french', 'en:1'],
#  'teams_tags': ['stakano', 'chocolatine'],
#  'last_editor': 'charlesnepote',
#  'purchase_places': 'France',
#  'pnns_groups_1': 'Fat and sauces',
#  'teams': 'stakano,chocolatine',
#  'nova_group': 4,
#  'ingredients_analysis_tags': ['en:palm-oil-content-unknown',
#   'en:vegan-status-unknown',
#   'en:vegetarian-status-unknown'],
#  'ingredients_that_may_be_from_palm_oil_tags': [],
#  'ecoscore_score': 78.4170138323676,
#  'nutrition_grades_tags': ['b'],
#  'complete': 0,
#  'environment_impact_level_tags': [],
#  'packagings': [{'material': 'en:glass'}],
#  'additives_n': 1,
#  'states_tags': ['en:to-be-completed',
#   'en:nutrition-facts-completed',
#   'en:ingredients-completed',
#   'en:expiration-date-to-be-completed',
#   'en:packaging-code-to-be-completed',
#   'en:characteristics-to-be-completed',
#   'en:origins-to-be-completed',
#   'en:categories-completed',
#   'en:brands-completed',
#   'en:packaging-completed',
#   'en:quantity-completed',
#   'en:product-name-completed',
#   'en:photos-to-be-validated',
#   'en:packaging-photo-to-be-selected',
#   'en:nutrition-photo-selected',
#   'en:ingredients-photo-selected',
#   'en:front-photo-selected',
#   'en:photos-uploaded'],
#  'nutriscore_score': 2,
#  'last_modified_t': 1610702480,
#  'photographers_tags': ['kiliweb', 'openfoodfacts-contributors'],
#  'nova_group_debug': ' -- ingredients/en:sugar : 3 -- ingredients/en:flavouring : 4',
#  'data_quality_warnings_tags': ['en:ingredients-ingredient-tag-length-greater-than-50',
#   'en:nutri-score-grade-from-label-does-not-match-calculated-grade',
#   'en:ecoscore-origins-of-ingredients-origins-are-100-percent-unknown',
#   'en:ecoscore-packaging-unspecified-shape'],
#  'brands_tags': ['panzani'],
#  'categories_properties': {'agribalyse_proxy_food_code:en': '11107'},
#  'allergens_hierarchy': [],
#  'origins_lc': 'fr',
#  'ingredients_tags': ['fr:pulpe-de-tomates-fraiches-avec-morceaux-et-purees-de-tomates-fraiches',
#   'fr:legumes-frais',
#   'en:vegetable',
#   'en:sunflower-oil',
#   'en:oil-and-fat',
#   'en:vegetable-oil-and-fat',
#   'en:vegetable-oil',
#   'en:basil',
#   'en:herb',
#   'en:sugar',
#   'en:salt',
#   'en:modified-corn-starch',
#   'en:starch',
#   'en:corn-starch',
#   'en:modified-starch',
#   'en:natural-flavouring',
#   'en:flavouring',
#   'en:onion-extract',
#   'en:root-vegetable',
#   'en:onion',
#   'en:parsley',
#   'en:carrot'],
#  'stores': '',
#  'interface_version_modified': '20190830',
#  'environment_impact_level': '',
#  'compared_to_category': 'en:tomato-sauces',
#  'popularity_key': 11,
#  'codes_tags': ['code-14',
#   '30383354190xxx',
#   '3038335419xxxx',
#   '303833541xxxxx',
#   '30383354xxxxxx',
#   '3038335xxxxxxx',
#   '303833xxxxxxxx',
#   '30383xxxxxxxxx',
#   '3038xxxxxxxxxx',
#   '303xxxxxxxxxxx',
#   '30xxxxxxxxxxxx',
#   '3xxxxxxxxxxxxx'],
#  'ingredients_text_with_allergens': "Pulpe de tomates fraîches avec morceaux et purées de tomates fraîches (85%), légumes frais 7% (oignons, carottes), huile de tournesol, basilic 1,4%, sucre, sel, amidon transformé de maïs, arôme naturel, extrait d'oignon, persil",
#  'informers_tags': ['yuka.UW8wQ0lyNGFoTVJSa3NJMzhVM3Arc2h0eU1XRmZFYVNOYk1iSVE9PQ',
#   'kiliweb',
#   'roboto-app',
#   'openfoodfacts-contributors',
#   'charlesnepote'],
#  'labels_hierarchy': ['en:nutriscore', 'en:nutriscore-grade-a'],
#  'additives_old_tags': [],
#  'product_name': 'basilic',
#  'quantity': '210 g',
#  'origins_tags': [],
#  'nutrition_data': 'on',
#  'ingredients_text_fr': "Pulpe de tomates fraîches avec morceaux et purées de tomates fraîches (85%), légumes frais 7% (oignons, carottes), huile de tournesol, basilic 1,4%, sucre, sel, amidon transformé de maïs, arôme naturel, extrait d'oignon, persil",
#  'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients': 1,
#  'ingredients_from_or_that_may_be_from_palm_oil_n': 0,
#  'nutriscore_grade': 'b',
#  'nutriscore_score_opposite': -2,
#  'categories': 'Epicerie,Sauces,Sauces tomate',
#  'packaging_tags': ['verre'],
#  'misc_tags': ['en:nutrition-fruits-vegetables-nuts-estimate-from-ingredients',
#   'en:nutrition-all-nutriscore-values-known',
#   'en:nutriscore-computed',
#   'en:ecoscore-missing-data-warning',
#   'en:ecoscore-computed'],
#  'additives_original_tags': ['en:e14xx'],
#  'ingredients_from_palm_oil_n': 0,
#  'manufacturing_places_tags': [],
#  'nutrient_levels_tags': ['en:fat-in-moderate-quantity',
#   'en:saturated-fat-in-low-quantity',
#   'en:sugars-in-moderate-quantity',
#   'en:salt-in-moderate-quantity'],
#  'data_quality_info_tags': ['en:packaging-data-incomplete',
#   'en:ingredients-percent-analysis-ok',
#   'en:carbon-footprint-from-known-ingredients-but-not-from-meat-or-fish'],
#  'nutrition_grade_fr': 'b',
#  'ingredients_text_with_allergens_fr': "Pulpe de tomates fraîches avec morceaux et purées de tomates fraîches (85%), légumes frais 7% (oignons, carottes), huile de tournesol, basilic 1,4%, sucre, sel, amidon transformé de maïs, arôme naturel, extrait d'oignon, persil",
#  'states': 'en:to-be-completed, en:nutrition-facts-completed, en:ingredients-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:origins-to-be-completed, en:categories-completed, en:brands-completed, en:packaging-completed, en:quantity-completed, en:product-name-completed, en:photos-to-be-validated, en:packaging-photo-to-be-selected, en:nutrition-photo-selected, en:ingredients-photo-selected, en:front-photo-selected, en:photos-uploaded',
#  'nutrient_levels': {'salt': 'moderate',
#   'saturated-fat': 'low',
#   'sugars': 'moderate',
#   'fat': 'moderate'},
#  'traces_hierarchy': [],
#  'emb_codes_tags': [],
#  'nutrition_data_per': '100g',
#  'allergens_tags': [],
#  'categories_properties_tags': ['all-products',
#   'categories-known',
#   'agribalyse-food-code-unknown',
#   'agribalyse-proxy-food-code-11107',
#   'agribalyse-proxy-food-code-known',
#   'ciqual-food-code-unknown',
#   'agribalyse-known',
#   'agribalyse-11107'],
#  'allergens': '',
#  'generic_name_fr': '',
#  'last_image_t': 1608035968,
#  'nutrition_score_beverage': 0,
#  'languages_codes': {'fr': 5},
#  'completeness': 0.7874999999999999,
#  'last_image_dates_tags': ['2020-12-15', '2020-12', '2020'],
#  'cities_tags': [],
#  'nutrition_data_prepared': '',
#  'nucleotides_tags': [],
#  'packaging_text': '',
#  'data_quality_tags': ['en:packaging-data-incomplete',
#   'en:ingredients-percent-analysis-ok',
#   'en:carbon-footprint-from-known-ingredients-but-not-from-meat-or-fish',
#   'en:ingredients-ingredient-tag-length-greater-than-50',
#   'en:nutri-score-grade-from-label-does-not-match-calculated-grade',
#   'en:ecoscore-origins-of-ingredients-origins-are-100-percent-unknown',
#   'en:ecoscore-packaging-unspecified-shape'],
#  'ecoscore_grade': 'b',
#  'pnns_groups_1_tags': ['fat-and-sauces', 'known'],
#  'interface_version_created': '20120622',
#  'brands': 'panzani',
#  'languages': {'en:french': 5},
#  'sortkey': 1610702480,
#  'allergens_from_user': '(fr) ',
#  'pnns_groups_2': 'Dressings and sauces',
#  'origins': '',
#  'allergens_lc': 'fr'}

# %%
import pandas as pd

cursor = rawCollection.find({'countries':'France'},
                       {"ingredients.text":1,
                        "ingredients.vegan":1,
                        "ingredients.vegetarian":1,
                        "ecoscore_data.agribalyse.name_fr":1,
                        "code":1,
                        "countries":1,
                        "nutriscore_grade":1,
                        "categories":1,
                        "ecoscore_grade":1,
                        "product_name_fr":1,
                        "product_name":1,
                        "generic_name_fr":1,
                        "generic_name":1,
                       })

produits_df = pd.DataFrame(list(cursor))
print(produits_df.head())
# Out:
#               _id       product_name_fr  \
# 0  30383354190402               basilic
# 1              00             lignaform
# 2           00000  Galette Bretonne bio
# 3   0000000000017      Vitória crackers
# 4   0000000000031                 Cacao
#
#                                          ingredients  \
# 0  [{'text': 'Pulpe de tomates fraîches avec morc...
# 1  [{'text': 'Farine de blé', 'vegan': 'yes', 've...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                        ecoscore_data            code  \
# 0  {'agribalyse': {'name_fr': 'Sauce tomate aux o...  30383354190402
# 1                                                NaN              00
# 2                                 {'agribalyse': {}}           00000
# 3                                 {'agribalyse': {}}   0000000000017
# 4                                 {'agribalyse': {}}   0000000000031
#
#   countries nutriscore_grade  \
# 0    France                b
# 1    France                c
# 2    France              NaN
# 3    France              NaN
# 4    France              NaN
#
#                                           categories ecoscore_grade
# 0                      Epicerie,Sauces,Sauces tomate              b
# 1  Snacks, Snacks sucrés, Biscuits et gâteaux, Bi...            NaN
# 2                                                NaN        unknown
# 3                                                NaN        unknown
# 4                                                NaN        unknown

# %%
# Out:
# _id                      0000000001001
# product_name_fr                    NaN
# ingredients                         []
# ecoscore_data       {'agribalyse': {}}
# code                     0000000001001
# countries                       France
# nutriscore_grade                   NaN
# categories                         NaN
# ecoscore_grade                 unknown
# Name: 12, dtype: object
